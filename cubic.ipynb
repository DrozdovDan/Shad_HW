# %%
import numpy as np

# %%
class Node:
    def __init__(state: np.ndarray):
        self.state = state.reshape(3, 3, 3)
        self.central_state = 13
        central_idx = np.argwhere(self.state == self.central_state)
        self.state[1, 1, 1], self.state[*central_idx.tolist()] = self.state[*central_idx.tolist()], self.state[1, 1, 1]

    def get_neighbours:
